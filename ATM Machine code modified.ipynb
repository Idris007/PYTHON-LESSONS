# %% [markdown]
# # ATM Machine code/Modified

# %%
bankname = ('BANK X')
pins = ['1888', '1999', '1234', '1212']
user = ['Mr Gbabx', 'Mr wande', 'Bisola', 'Amina']
balance = [40000, 150000, 10000, 200000]
transactions = [1, 2, 3, 4]
global account
account = ['savings', 'current', 'savings', 'savings']
pin_vault = []
account_vault = []

def enter_pin():
    global new_pin
    new_pin = ''
    count = 4
    for x in 'pin':
        print('Welcome, to perfom a transaction enter pin.....')
        global enter
        enter = input(':')
        pin_vault.append(enter)
        new_pin = enter
        count = count - 1
        if enter == pins[0] and enter == pin_vault[0]:
            Total_balance.append(balance[0])
            print('Pin accepted proceed with transaction...')
            print(f'''
Welcome {user[0]} to {bankname}, To perform the following transactions
1. Withdrawal
2. Transfer
3. Buy Airtime
4. Pay bills
''')
            global num1
            num1 = input('Enter transaction option:')
            enter = input('1. Savings\n2. Current\nEnter account type: ')
            if enter == '1':
                account_vault.clear()
                account_vault.append('savings')
                if account_vault[0] == account[0]:
                    print('You may proceed...')
                    processes()
                elif account_vault[0] != account[0]:
                    print('Wrong account selection')
                    proceed = input('Do you wish to proceed...\n1. Yes\n2. No\n:')
                    if proceed == '1':
                        enter_pin()
                    else:
                        print('You may take your card...')
                        break
                    break
                break
            elif enter == '2':
                account_vault.clear()
                account_vault.append('current')
                if account_vault[0] == account[0]:
                    print('You may proceed...')
                    processes()
                elif account_vault[0] != account[0]:
                    print('Wrong account selection')
                    proceed = input('Do you wish to proceed...\n1. Yes\n2. No\n:')
                    if proceed == '1':
                        enter_pin()
                    else:
                        print('You may take your card...')
                        break
                    break
                break
            break
        elif enter == pins[1] and enter == pin_vault[0]:
            Total_balance.append(balance[1])
            print('Pin accepted proceed with transaction...')
            print(f'''
Welcome {user[1]} to {bankname}, To perform the following transactions
1. Withdrawal
2. Transfer
3. Buy Airtime
4. Pay bills
''')
            num1 = input('Enter transaction option:')
            enter = input('1. Savings\n2. Current\nEnter account type: ')
            if enter == '1':
                account_vault.clear()
                account_vault.append('savings')
                if account_vault[0] == account[1]:
                    print('You may proceed...')
                    processes()
                elif account_vault[0] != account[1]:
                    print('Wrong account selection')
                    proceed = input('Do you wish to proceed...\n1. Yes\n2. No\n:')
                    if proceed == '1':
                        enter_pin()
                    else:
                        print('You may take your card...')
                        break
                    break
                break
            elif enter == '2':
                account_vault.clear()
                account_vault.append('current')
                if account_vault[0] == account[1]:
                    print('You may proceed...')
                    processes()
                elif account_vault[0] != account[1]:
                    print('Wrong account selection')
                    proceed = input('Do you wish to proceed...\n1. Yes\n2. No\n:')
                    if proceed == '1':
                        enter_pin()
                    else:
                        print('You may take your card...')
                        break
                    break
                break
            break
        elif enter == pins[2] and enter == pin_vault[0]:
            Total_balance.append(balance[2])
            print('Pin accepted proceed with transaction...')
            print(f'''
Welcome {user[2]} to {bankname}, To perform the following transactions
1. Withdrawal
2. Transfer
3. Buy Airtime
4. Pay bills
''')
            num1 = input('Enter transaction option:')
            enter = input('1. Savings\n2. Current\nEnter account type: ')
            if enter == '1':
                account_vault.clear()
                account_vault.append('savings')
                if account_vault[0] == account[2]:
                    print('You may proceed...')
                    processes()
                elif account_vault[0] != account[2]:
                    print('Wrong account selection')
                    proceed = input('Do you wish to proceed...\n1. Yes\n2. No\n:')
                    if proceed == '1':
                        enter_pin()
                    else:
                        print('You may take your card...')
                        break
                    break
                break
            elif enter == '2':
                account_vault.clear()
                account_vault.append('current')
                if account_vault[0] == account[2]:
                    print('You may proceed...')
                    processes()
                elif account_vault[0] != account[2]:
                    print('Wrong account selection')
                    proceed = input('Do you wish to proceed...\n1. Yes\n2. No\n:')
                    if proceed == '1':
                        enter_pin()
                    else:
                        print('You may take your card...')
                        break
                    break
                break
            break
        elif enter == pins[3] and enter == pin_vault[0]:
            Total_balance.append(balance[3])
            print('Pin accepted proceed with transaction...')
            print(f'''
Welcome {user[3]} to {bankname}, To perform the following transactions
1. Withdrawal
2. Transfer
3. Buy Airtime
4. Pay bills
''')
            num1 = input('Enter transaction option:')
            enter = input('1. Savings\n2. Current\nEnter account type: ')
            if enter == '1':
                account_vault.clear()
                account_vault.append('savings')
                if account_vault[0] == account[3]:
                    print('You may proceed...')
                    processes()
                elif account_vault[0] != account[3]:
                    print('Wrong account selection')
                    proceed = input('Do you wish to proceed...\n1. Yes\n2. No\n:')
                    if proceed == '1':
                        enter_pin()
                    else:
                        print('You may take your card...')
                        break
                    break
                break
            elif enter == '2':
                account_vault.clear()
                account_vault.append('current')
                if account_vault[0] == account[3]:
                    print('You may proceed...')
                    processes()
                elif account_vault[0] != account[3]:
                    print('Wrong account selection')
                    proceed = input('Do you wish to proceed...\n1. Yes\n2. No\n:')
                    if proceed == '1':
                        enter_pin()
                    else:
                        print('You may take your card...')
                        break
                    break
                break
            break
        elif enter != pins[0:3]:
            print(f'You have {count - 1} tries left')
            if count == 1:
                print('You have entered a wrong pin consecutively\nYou may take your card...')
                break
        elif enter == pins[0:3] and enter != pin_vault[0]:
            print('Pin mismatch...')
            break




global Total_balance
Total_balance = []

class ATM:
    def __init__(self):
        self.balance = balance

    def withdrawal(self,cash):
        print('1. 500\n2. 1000\n3. 2000\n4. 5000\n5. Others')
        select_option = input('Select option:')
        if select_option == '5':
            debit = int(input('Enter amount:'))
            if  cash > debit:
                y = cash - debit
                Total_balance.clear()
                Total_balance.append(y)
                print(f'Your new balance is {y}')
            else:
                print('Insufficient balance...')
        elif select_option == '1' or '2' or '3' or '4':
            if select_option == '1':
                if cash > 500:
                    x = cash - 500
                    Total_balance.clear()
                    Total_balance.append(x)
                    print(f'Your new balance is {x}')
                else:
                    print('Insufficient balance...')

            elif select_option == '2':
                if cash > 1000:
                    z = cash - 1000
                    Total_balance.clear()
                    Total_balance.append(z)
                    print(f'Your new balance is {z}')
                else:
                    print('Insufficient balance...')
            elif select_option == '3':
                if cash > 2000:
                    a = cash - 2000
                    Total_balance.clear()
                    Total_balance.append(a)
                    print(f'Your new balance is {a}')
                else:
                    print('Insufficient balance...')
            elif select_option == '4':
                if cash > 5000:
                    b = cash - 5000
                    Total_balance.clear()
                    Total_balance.append(b)
                    print(f'Your new balance is {b}')
                else:
                    print('Insufficient balance...')


    def transfer(self,cash):
        account_number = input('Enter account number:')
        if len(account_number) == 10:
            print('1. 500\n2. 1000\n3. 2000\n4. 5000\n5. Others')
            select_option = input('Enter selection')

            if select_option == '5':
                amount = int(input('Enter amount...'))
                if cash > amount:
                    x = cash - amount
                    Total_balance.clear()
                    Total_balance.append(x)
                    print(f'Your new balance is {x}')
                else:
                    print('Insufficient balance...')
            elif select_option == '1' or '2' or '3' or '4':
                if select_option == '1':
                    if cash > 500:
                        x = cash - 500
                        Total_balance.clear()
                        Total_balance.append(x)
                        print(f'Your new balance is {x}')
                    else:
                        print('Insufficient balance...')

                elif select_option == '2':
                    if cash > 1000:
                        z = cash - 1000
                        Total_balance.clear()
                        Total_balance.append(z)
                        print(f'Your new balance is {z}')
                    else:
                        print('Insufficient balance...')
                elif select_option == '3':
                    if cash > 2000:
                        a = cash - 2000
                        Total_balance.clear()
                        Total_balance.append(a)
                        print(f'Your new balance is {a}')
                    else:
                        print('Insufficient balance...')
                elif select_option == '4':
                    if cash > 5000:
                        b = cash - 5000
                        Total_balance.clear()
                        Total_balance.append(b)
                        print(f'Your new balance is {b}')
                    else:
                        print('Insufficient balance...')
        else:
            print('Incorrect account number entry...')
def processes():
    while True:
        enter_option = input('Confirm transaction option:')
        if num1 == enter_option:
            if enter_option == '1':
                ATM().withdrawal(Total_balance[0])
                proceed = input('Do you wish to perfom another transaction\n1. Yes\n2. No\n:')
                if proceed == '1':
                    enter_pin()
                else:
                    print('Thank you...\nYou may take your card...')
                    break
                break

            elif enter_option == '2':
                ATM().transfer(Total_balance[0])
                proceed = input('Do you wish to perfom another transaction\n1. Yes\n2. No\n:')
                if proceed == '1':
                    enter_pin()
                else:
                    print('Thank you...\nYou may take your card...')
                    break
                break
            break
        else:
            print('Input mismatch...')
            processes()
            break

        break

enter_pin()
# Out:
# Welcome, to perfom a transaction enter pin.....
# :1212
# Pin accepted proceed with transaction...
#
# Welcome Amina to BANK X, To perform the following transactions
# 1. Withdrawal
# 2. Transfer
# 3. Buy Airtime
# 4. Pay bills
#
# Enter transaction option:1
# 1. Savings
# 2. Current
# Enter account type: 2
# Wrong account selection
