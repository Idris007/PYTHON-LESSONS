# %%
bank_list = [1, 2, 3, 4, 5, 6]
bankname = ('BANK X')
pins = ['1888', '1999', '1234', '1212']
user = ['Mr Gbabx', 'Mr wande', 'Bisola', 'Amina']
account_type = [1, 2]
balance = [40000, 150000, 10000, 200000]
transactions = [1, 2, 3, 4]
balance_list = [500, 1000, 2000, 3000, 5000, 10000, 20000]
account = ['savings', 'current']



# ATM MACHINE CODE MODIFIED

bank_name = ('BANK X')
print(
f'''
Welcome to {bank_name}
Please insert your card....
'''
)



def transfer(bank_transfer, amount, balance):
    if bank_transfer == bank_list[0]:
        if balance > amount:
            balance_check = balance - amount
            balance_check = balance
            print(f'Your new balance is {balance_check}')
        else:
            print('Insufficient funds')

    elif bank_transfer == bank_list[1]:
        if balance > amount:
            balance_check = balance - amount
            balance_check = balance
            print(f'Your new balance is {balance_check}')
        else:
            print('Insufficient funds')

    elif bank_transfer == bank_list[2]:
        if balance > amount:
            balance_check = balance - amount
            balance_check = balance
            print(f'Your new balance is {balance_check}')
        else:
            print('Insufficient funds')

    elif bank_transfer == bank_list[3]:
        if balance > amount:
            balance_check = balance - amount
            balance_check = balance
            print(f'Your new balance is {balance_check}')
        else:
            print('Insufficient funds')

    elif bank_transfer == bank_list[4]:
        if balance > amount:
            balance_check = balance - amount
            balance_check = balance
            print(f'Your new balance is {balance_check}')
        else:
            print('Insufficient funds')

    elif bank_transfer == bank_list[5]:
        if balance > amount:
            balance_check = balance - amount
            balance_check = balance
            print(f'Your new balance is {balance_check}')
        else:
            print('Insufficient funds')


def bank_name(bankname):
    if bankname == bank_list[0]:
        print('You have selected FBN...')
    elif bankname == bank_list[1]:
        print('You have selected Union Bank...')
    elif bankname == bank_list[2]:
        print('You have selected UBA...')
    elif bankname == bank_list[3]:
        print('You have selected GTB...')
    elif bankname == bank_list[4]:
        print('You have selected Access Bank...')
    elif bankname == bank_list[5]:
        print('You have selected FCMB...')


def airtime(phonenumber, amount, balance):
    print('Enter 11 digit phone number...')
    if len(phonenumber) == 11:
        print('Phone number correct...')
        balance_check = balance - amount
        print(f'Your new balance is {balance_check}...')
    elif len(phonenumber) > 11:
        print('You have enter an incorrect number...')


def enter_pin():
    global new_pin
    new_pin = ''
    count = 4
    for x in 'pin':
        print('To perfom transaction enter pin.....')
        enter = (input(':'))
        new_pin = enter
        count = count - 1
        if enter == pins[0]:
            print('Pin accepted proceed with transaction...')
            print(f'''
Welcome {user[0]} to {bankname}, To perform the following transactions
1. Withdrawal
2. Transfer
3. Buy Airtime
4. Pay bills
''')
            break
        elif enter == pins[1]:
            print('Pin accepted proceed with transaction...')
            print(f'''
Welcome {user[1]} to {bankname}, To perform the following transactions
1. Withdrawal
2. Transfer
3. Buy Airtime
4. Pay bills
''')
            break
        elif enter == pins[2]:
            print('Pin accepted proceed with transaction...')
            print(f'''
Welcome {user[2]} to {bankname}, To perform the following transactions
1. Withdrawal
2. Transfer
3. Buy Airtime
4. Pay bills
''')
            break
        elif enter == pins[3]:
            print('Pin accepted proceed with transaction...')
            print(f'''
Welcome {user[3]} to {bankname}, To perform the following transactions
1. Withdrawal
2. Transfer
3. Buy Airtime
4. Pay bills
''')
            break
        elif enter != pins[0:3]:
            print(f'You have {count - 1} tries left')
        elif count == 0:
            break


def confirm_pin():
    print(f'''
Welcome {user[0]} to {bankname}''')
    if (input('Do you wish to proceed \n 1. yes \n 2. no \n:'))== '1':
        pin1 = input('To continue confirm your pin...')
        if new_pin == pin1:
            print('Pin correct proceed...')
            print(f'''
        Welcome {user[0]} to {bankname}, To perform the following transactions
        1. Withdrawal
        2. Transfer
        3. Buy Airtime
        4. Pay bills
        ''')
        else:
            print('Wrong pin...')
    elif (input('Do you wish to proceed \n 1. yes \ 2. no')) == '2':
        print('You may take your card...')


def withdrawal():
    global new_amount1
    new_amount1 = ''
    global money
    money = ''
    global another
    another = ['1', '2']
    global do_you
    do_you = ''
    transact = int(input('Confirm option to continue:'))
    while True:
        cash_list = ['1', '2', '3', '4', '5', '6', '7', '8']
        if transact == account_type[0]:
            account_select = int(input('Enter your account type:... \n 1. Savings \n 2. Current \n: '))
            print(f'You have selected {account[0]} account...')
            print(
                'To withdraw the following amount...\n1. 500 \n2. 1000 \n3. 2000 \n4. 3000 \n5. 5000 \n6. 10000 \n7. 20000 \n8. other')
            selection = input('Enter option...')
            if account_select == account_type[0]:
                if selection == '8':
                    wish = ''
                    wish_1 = input(f'To continue enter a yes or no {wish}')
                    wish = wish_1
                    x = 0
                    while True:
                        x = x + 1
                        if x == 1:
                            if wish == 'no':
                                print('Thanks for your time...')
                                print('Please take your card...')
                                enter_pin()
                                confirm_pin()
                                break
                            elif wish == 'yes':
                                try:
                                    debit = int(input('Enter amount you wish to withdraw: '))
                                    if debit > balance[0]:
                                        print('Insufficient balance')
                                        print('Do you wish to perform another transaction...')
                                        break
                                    else:
                                        new_balance = balance[0] - debit
                                        balance[0] = new_balance
                                        print(f'Your new balance is {new_balance}')
                                        print('Please take your cash...')
                                        print('Do you wish to perform another transaction...')
                                        break
                                except:
                                    print('Invalid input...')
                                    print('Do you wish to perform another transaction...')
                                    break

                            break
                        break
                elif selection == cash_list[0]:
                    new_amount = balance[0] - balance_list[0]
                    print(f'Your new balance is {new_amount}')
                    if (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n'
                              f':')) == another[0]:
                        money = new_amount
                        second_withdrawal()
                    elif (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n'
                              f':')) == another[1]:
                        print('You may take your card...')
                        break
                elif selection == cash_list[1]:
                    new_amount = balance[0] - balance_list[1]
                    print(f'Your new balance is {new_amount}')
                    if (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n:')) == another[0]:
                        money = new_amount
                        second_withdrawal()
                    elif (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n'
                              f':')) == another[1]:
                        print('You may take your card...')
                        break
                elif selection == cash_list[2]:
                    new_amount = balance[0] - balance_list[2]
                    print(f'Your new balance is {new_amount}')
                    if (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n:')) == another[0]:
                        money = new_amount
                        second_withdrawal()
                    elif (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n'
                              f':')) == another[1]:
                        print('You may take your card...')
                        break
                elif selection == cash_list[3]:
                    new_amount = balance[0] - balance_list[3]
                    print(f'Your new balance is {new_amount}')
                    if (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n:')) == another[0]:
                        money = new_amount
                        second_withdrawal()
                    elif (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n'
                              f':')) == another[1]:
                        print('You may take your card...')
                        break
                elif selection == cash_list[4]:
                    new_amount = balance[0] - balance_list[4]
                    print(f'Your new balance is {new_amount}')
                    if (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n:')) == another[0]:
                        money = new_amount
                        second_withdrawal()
                    elif (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n'
                              f':')) == another[1]:
                        print('You may take your card...')
                        break
                elif selection == cash_list[5]:
                    new_amount = balance[0] - balance_list[5]
                    print(f'Your new balance is {new_amount}')
                    if (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n:')) == another[0]:
                        money = new_amount
                        second_withdrawal()
                    elif (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n'
                              f':')) == another[1]:
                        print('You may take your card...')
                        break
                elif selection == cash_list[6]:
                    new_amount = balance[0] - balance_list[6]
                    print(f'Your new balance is {new_amount}')
                    if (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n:')) == another[0]:
                        money = new_amount
                        second_withdrawal()
                    elif (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no \n'
                              f':')) == another[1]:
                        print('You may take your card...')
                        break
            elif account_select == account_type[1]:
                print('Your account selection is wrong...')
            else:
                print('Invalid account type selection')
                print('Do you wish to perform another transaction...')

            break

        break


def restart():

    confirm_pin()

    transactions = [1, 2, 3, 4]
    while True:
        transact = int(input('Choose option to continue:'))
        if transact == transactions[1]:
            print('Please select bank \n 1. FBN \n 2. Union Bank \n 3. UBA \n 4. GTB \n 5. Access Bank \n 6. FCMB')
            bank_transfer = int(input('Please enter the bank you wish to send money to.'))
            bank_name(bank_transfer)
            amount = int(input('Enter the amount you wish to send:'))
            transfer(bank_transfer, amount, balance[0])
            break
        elif transact == transactions[2]:
            print('''Please select the network you wish to buy Airtime...
                             1. MTN
                             2. Glo
                             3. Airtel
                             4. Etisalat
                             ''')
            phone_number = input(':')
            break
        elif transact == transactions[3]:
            print('To pay \n 1. PHCN \n 2. LAWMA \n 3. WATER BOARD')

        elif transact == transactions[0]:
            withdrawal()
        break


choice = ['1', '2']
first = ''
second = ''
def second_withdrawal():
    if (input(f'{do_you} Confirm selection...\n1. yes \n2. no \n:')) == choice[0]:
        print(f'''
Welcome {user[0]} to {bankname}, To perform the following transactions
1. Withdrawal
2. Transfer
3. Buy Airtime
4. Pay bills
            ''')
        if (input('Enter selection...')) == '1':
            if (input('Enter your account type:... \n 1. Savings \n 2. Current \n: ')) == choice[0]:
                print('To withdraw the following amount...\n1. 500 \n2. 1000 \n3. 2000 \n4. 3000 \n5. 5000 \n6. 10000 \n7. 20000 \n8. other')
                while True:
                    if (input('Enter amount: ')) == '8':
                        try:
                            debit = int(input('Enter amount you wish to withdraw: '))
                            if debit > money:
                                print('Insufficient balance')
                                print('Do you wish to perform another transaction...')
                                restart()
                            else:
                                new_balance = money - debit
                                print(f'Your new balance is {new_balance}')
                                print('Please take your cash...')
                                print('Do you wish to perform another transaction...')
                                restart()

                        except:
                            print('Invalid input...')
                            print('Do you wish to perform another transaction...')
                            restart()
                        break
                    elif (input('Confirm selection: ')) == '1':
                        new_amount1 = money - balance_list[0]
                        print(f'Your new balance is {new_amount1}')
                        restart()
                        break
                    elif (input('Confirm selection: ')) == '2':
                        new_amount1 = money - balance_list[1]
                        print(f'Your new balance is {new_amount1}')
                        restart()
                        break
                    elif (input('Confirm selection: ')) == '3':
                        new_amount1 = money - balance_list[2]
                        print(f'Your new balance is {new_amount1}')
                        restart()
                        break
                    elif (input('Confirm selection: ')) == '4':
                        new_amount1 = money - balance_list[3]
                        print(f'Your new balance is {new_amount1}')
                        restart()
                        break
                    elif (input('Confirm selection: ')) == '5':
                        new_amount1 = money - balance_list[4]
                        print(f'Your new balance is {new_amount1}')
                        restart()
                        break
                    elif (input('Confirm selection: ')) == '6':
                        new_amount1 = money - balance_list[5]
                        print(f'Your new balance is {new_amount1}')
                        restart()
                        break
                    elif (input('Confirm selection: ')) == '7':
                        new_amount1 = money - balance_list[6]
                        print(f'Your new balance is {new_amount1}')
                        restart()
                        break
                    break

        elif (input('Enter selection...')) == '2':
            transfer(bank_transfer, amount, balance)

        elif (input('Enter selection...')) == '3':
            airtime(phonenumber, amount, balance)

        elif (input('Enter selection...')) == '4':
            pass

    elif (input(f'{do_you} Do you wish to perform another transaction...\n1. yes \n2. no')) == choice[1]:
        print('You may take your card...')


print('Card inserted...')

enter_pin()



transactions = [1, 2, 3, 4]
while True:
    transact = int(input('Choose option to continue:'))
    if transact == transactions[1]:
        print('Please select bank \n 1. FBN \n 2. Union Bank \n 3. UBA \n 4. GTB \n 5. Access Bank \n 6. FCMB')
        bank_transfer = int(input('Please enter the bank you wish to send money to.'))
        bank_name(bank_transfer)
        amount = int(input('Enter the amount you wish to send:'))
        transfer(bank_transfer, amount, balance[0])
        break
    elif transact == transactions[2]:
        print('''
Please select the network you wish to buy Airtime...
1. MTN
2. Glo
3. Airtel
4. Etisalat
''')
        phone_number = input(':')
        break
    elif transact == transactions[3]:
        print('To pay \n 1. PHCN \n 2. LAWMA \n 3. WATER BOARD')

    elif transact == transactions[0]:
        withdrawal()
        second_withdrawal()
    break
# Out:
# Welcome to BANK X
# Please insert your card....
#
# Card inserted...
# To perfom transaction enter pin.....
